# %% [markdown]
# <a href="https://colab.research.google.com/github/sumanthchennamsetty/HPC_assignment1/blob/main/graphs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
x = [1,2,4,6,8,10,12,14,16]
y = [1.191182,
0.602799,
0.591382,
0.367314,
0.326921,
0.315832,
0.335574,
0.316693,
0.334408]
plt.bar(x,y)
plt.title("Matrix size 512 by Using OMM")
plt.xlabel("Threads by fixing the Matrix Size")
plt.ylabel("RunTime")
plt.show()

# %%
x = [1,2,4,6,8,10,12,14,16]
y = [
9.613506,
5.607921,
4.001354,
2.276934,
1.963363,
1.914987,
1.9168,
1.924242,
1.924429]
plt.bar(x,y)
plt.title("Matrix size 1024 by Using OMM")
plt.xlabel("Threads by fixing the Matrix Size")
plt.ylabel("RunTime")
plt.show()

# %%
x = [1,2,4,6,8,10,12,14,16]
y = [32.971,35.280,38.080,35.11,36.106,34.686,35.90,34.701,34.132]
plt.bar(x,y)
plt.title("Matrix size 2048 by Using OMM")
plt.xlabel("Threads by fixing the Matrix Size")
plt.ylabel("RunTime")
plt.show()

# %% [markdown]
# OMM THREADS FIXED

# %%
import numpy as np
import matplotlib.pyplot as plt
x = [512,1024,2048]
y = [0.174558,1.228490,24.078737]
plt.plot(x,y)
plt.title("Runtime vs Matrix Sizes by fixing number of threads")
plt.xlabel("Matrix Sizes by fixing number of threads as 2")
plt.ylabel("RunTime")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x = [512,1024,2048]
y = [0.104720,0.687993,13.096906]
plt.plot(x,y)
plt.title("Runtime vs Matrix Sizes by fixing number of threads")
plt.xlabel("Matrix Sizes by fixing number of threads as 4")
plt.ylabel("RunTime")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x = [512,1024,2048]
y = [0.087573,0.770016,	15.703731]
plt.plot(x,y)
plt.title("Runtime vs Matrix Sizes by fixing number of threads")
plt.xlabel("Matrix Sizes by fixing number of threads as 6")
plt.ylabel("RunTime")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x = [512,1024,2048]
y = [0.076708,0.587943,11.873107]
plt.plot(x,y)
plt.title("Runtime vs Matrix Sizes by fixing number of threads")
plt.xlabel("Matrix Sizes by fixing number of threads as 8")
plt.ylabel("RunTime")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x = [512,1024,2048]
y = [0.076772,	0.591114,12.788856]
plt.plot(x,y)
plt.title("Runtime vs Matrix Sizes by fixing number of threads")
plt.xlabel("Matrix Sizes by fixing number of threads as 10")
plt.ylabel("RunTime")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x = [512,1024,2048]
y = [0.076232,0.589670,12.697551]
plt.plot(x,y)
plt.title("Runtime vs Matrix Sizes by fixing number of threads")
plt.xlabel("Matrix Sizes by fixing number of threads as 12")
plt.ylabel("RunTime")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x = [512,1024,2048]
y = [0.076727,0.583250,11.962854]
plt.plot(x,y)
plt.title("Runtime vs Matrix Sizes by fixing number of threads")
plt.xlabel("Matrix Sizes by fixing number of threads as 14")
plt.ylabel("RunTime")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x = [512,1024,2048]
y = [0.083124,0.648307,11.765105]
plt.plot(x,y)
plt.title("Runtime vs Matrix Sizes by fixing number of threads")
plt.xlabel("Matrix Sizes by fixing number of threads as 16")
plt.ylabel("RunTime")
plt.show()

# %% [markdown]
# BMM THREADS VS RUNTIME & MATRIX SIZE CONSTANT

# %%
x = [1,2,4,6,8,10,12,14,16]
y = [27.007192,14.14786,7.210654,7.606915,5.849068,5.819001,5.383096,5.33335,5.270493]
plt.bar(x,y)
plt.title("Matrix size 2048 by Using BMM")
plt.xlabel("Threads by fixing the Matrix Size and Block size 4")
plt.ylabel("RunTime")
plt.show()

# %%
x = [1,2,4,6,8,10,12,14,16]
y = [24.458088,12.668468,6.515705,6.896674,5.341762,5.243082,4.922707,4.895309,4.757486]
plt.bar(x,y)
plt.title("Matrix size 2048 by Using BMM")
plt.xlabel("Threads by fixing the Matrix Size and Block size 8")
plt.ylabel("RunTime")
plt.show()

# %%
x = [1,2,4,6,8,10,12,14,16]
y = [23.310665,11.948860,6.212747,6.554240,4.993087,	4.928252,4.681713,4.612673,4.573514]
plt.bar(x,y)
plt.title("Matrix size 2048 by Using BMM")
plt.xlabel("Threads by fixing the Matrix Size and Block size 16")
plt.ylabel("RunTime")
plt.show()

# %%
x = [1,2,4,6,8,10,12,14,16]
y = [22.932157,
11.744982,
6.103499,
6.474765,
5.159184,
4.885187,
4.669524,
4.611549,
4.478429]
plt.bar(x,y)
plt.title("Matrix size 2048 by Using BMM")
plt.xlabel("Threads by fixing the Matrix Size and Block size 32")
plt.ylabel("RunTime")
plt.show()

# %%
x = [1,2,4,6,8,10,12,14,16]
y = [22.860416,
11.695689,
6.080964,
6.43398,
4.912793,
4.905135,
4.612101,
4.518318,
4.418193]
plt.bar(x,y)
plt.title("Matrix size 2048 by Using BMM")
plt.xlabel("Threads by fixing the Matrix Size and Block size 64")
plt.ylabel("RunTime")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = [1,2,4,6,8,10,12,14,16]
y = [5.249879,2.677897,1.402379,1.54002,1.419613,1.49554,1.490922,1.468537,1.39959]
plt.bar(x,y)
plt.title("Matrix size 1024 by Using BMM, block size 4")
plt.xlabel("Threads by fixing the Matrix Size")
plt.ylabel("RunTime")
plt.show()

# %%
x = [1,2,4,6,8,10,12,14,16]
y = [4.760007,2.44351,1.354469,1.35536,1.287222,1.390642,1.313313,1.339779,1.350572]
plt.bar(x,y)
plt.title("Matrix size 1024 by Using BMM, block size 8")
plt.xlabel("Threads by fixing the Matrix Size")
plt.ylabel("RunTime")
plt.show()

# %%
x = [1,2,4,6,8,10,12,14,16]
y = [4.28292,2.246802,1.313023,1.375988,1.281837,1.276216,1.282145,1.287281,1.269042]
plt.bar(x,y)
plt.title("Matrix size 1024 by Using BMM, block size 16")
plt.xlabel("Threads by fixing the Matrix Size")
plt.ylabel("RunTime")
plt.show()

# %%
x = [1,2,4,6,8,10,12,14,16]
y = [4.426677,2.317763,1.354208,1.429893,1.347878,1.347124,1.279,1.297409,1.253369]
plt.bar(x,y)
plt.title("Matrix size 1024 by Using BMM, block size 32")
plt.xlabel("Threads by fixing the Matrix Size")
plt.ylabel("RunTime")
plt.show()

# %%
x = [1,2,4,6,8,10,12,14,16]
y = [4.68163,3.378257,2.027657,1.884077,1.393503,1.463129,1.405027,1.392,1.375722]
plt.bar(x,y)
plt.title("Matrix size 1024 by Using BMM, block size 64")
plt.xlabel("Threads by fixing the Matrix Size")
plt.ylabel("RunTime")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = [1,2,4,6,8,10,12,14,16]
y = [1.826793,1.009601,0.643661,0.560209,0.481425,0.538589,0.478797,0.508502,0.502751]
plt.bar(x,y)
plt.title("Matrix size 512 by Using BMM, block size 4")
plt.xlabel("Threads by fixing the Matrix Size")
plt.ylabel("RunTime")
plt.show()

# %%
x = [1,2,4,6,8,10,12,14,16]
y = [1.706002,1.196682,0.663679,0.502704,0.462643,0.4759,0.497431,0.474309,0.443683]
plt.bar(x,y)
plt.title("Matrix size 512 by Using BMM, block size 8")
plt.xlabel("Threads by fixing the Matrix Size")
plt.ylabel("RunTime")
plt.show()

# %%
x = [1,2,4,6,8,10,12,14,16]
y = [1.896792,1.054832,0.641295,0.488611,0.476939,0.48055,0.489201,0.447048,0.459459]
plt.bar(x,y)
plt.title("Matrix size 512 by Using BMM, block size 16")
plt.xlabel("Threads by fixing the Matrix Size")
plt.ylabel("RunTime")
plt.show()

# %%
x = [1,2,4,6,8,10,12,14,16]
y = [1.741423,0.98301,0.625351,0.494904,0.455649,0.508175,0.557999,0.462546,0.46894]
plt.bar(x,y)
plt.title("Matrix size 512 by Using BMM, block size 32")
plt.xlabel("Threads by fixing the Matrix Size")
plt.ylabel("RunTime")
plt.show()

# %%
x = [1,2,4,6,8,10,12,14,16]
y = [1.712034,1.017414,0.599015,0.486776,0.511976,0.497247,0.470439,0.491457,0.462149]
plt.bar(x,y)
plt.title("Matrix size 512 by Using BMM, block size 64")
plt.xlabel("Threads by fixing the Matrix Size")
plt.ylabel("RunTime")
plt.show()

# %% [markdown]
# # BMM Runtime vs Matrix Sizes by fixing number of threads

# %%
import numpy as np
import matplotlib.pyplot as plt
x = [512,1024,2048]
y = [0.285523,2.079754,16.593193]
plt.plot(x,y)
plt.title(''' BMM - Runtime vs Matrix Sizes by fixing number of threads
BLOCK SIZE 4''')
plt.xlabel("Matrix Sizes by fixing number of threads as 2")
plt.ylabel("RunTime")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x = [512,1024,2048]
y = [0.166067,
1.090401,
8.753967]
plt.plot(x,y)
plt.title(''' BMM - Runtime vs Matrix Sizes by fixing number of threads
BLOCK SIZE 4''')
plt.xlabel("Matrix Sizes by fixing number of threads as 4")
plt.ylabel("RunTime")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x = [512,1024,2048]
y = [0.154523,
1.13508,
9.173047]
plt.plot(x,y)
plt.title(''' BMM - Runtime vs Matrix Sizes by fixing number of threads
BLOCK SIZE 4''')
plt.xlabel("Matrix Sizes by fixing number of threads as 6")
plt.ylabel("RunTime")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x = [512,1024,2048]
y = [0.179356,
0.883494,
7.495103]
plt.plot(x,y)
plt.title(''' BMM - Runtime vs Matrix Sizes by fixing number of threads
BLOCK SIZE 4''')
plt.xlabel("Matrix Sizes by fixing number of threads as 8")
plt.ylabel("RunTime")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x = [512,1024,2048]
y = [0.139104,
0.891066,
6.950553]
plt.plot(x,y)
plt.title(''' BMM - Runtime vs Matrix Sizes by fixing number of threads
BLOCK SIZE 4''')
plt.xlabel("Matrix Sizes by fixing number of threads as 10")
plt.ylabel("RunTime")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x = [512,1024,2048]
y = [0.141091,
0.868559,
6.547467]
plt.plot(x,y)
plt.title(''' BMM - Runtime vs Matrix Sizes by fixing number of threads
BLOCK SIZE 4''')
plt.xlabel("Matrix Sizes by fixing number of threads as 12")
plt.ylabel("RunTime")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x = [512,1024,2048]
y = [0.134498,0.843738,6.3596]
plt.plot(x,y)
plt.title(''' BMM - Runtime vs Matrix Sizes by fixing number of threads
BLOCK SIZE 4''')
plt.xlabel("Matrix Sizes by fixing number of threads as 14")
plt.ylabel("RunTime")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x = [512,1024,2048]
y = [0.146541,0.830554,6.250946]
plt.plot(x,y)
plt.title(''' BMM - Runtime vs Matrix Sizes by fixing number of threads
BLOCK SIZE 4''')
plt.xlabel("Matrix Sizes by fixing number of threads as 16")
plt.ylabel("RunTime")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x = [512,1024,2048]
y = [0.650399,10.253389,79.888657]
plt.plot(x,y)
plt.title('''Runtime vs Matrix Sizes by fixing number of threads
BLOCK SIZE - 16''')
plt.xlabel("Matrix Sizes by fixing number of threads as 2")
plt.ylabel("RunTime")
plt.show()

# %%
x = [512,1024,2048]
y = [0.595359,6.6753,52.525259]
plt.plot(x,y)
plt.title('''Runtime vs Matrix Sizes by fixing number of threads
BLOCK SIZE - 16''')
plt.xlabel("Matrix Sizes by fixing number of threads as 4")
plt.ylabel("RunTime")
plt.show()

# %%
x = [512,1024,2048]
y = [0.407583,4.596492,37.722524]
plt.plot(x,y)
plt.title('''Runtime vs Matrix Sizes by fixing number of threads
BLOCK SIZE - 16''')
plt.xlabel("Matrix Sizes by fixing number of threads as 6")
plt.ylabel("RunTime")
plt.show()

# %%
x = [512,1024,2048]
y = [0.56208,3.831431,34.529853]
plt.plot(x,y)
plt.title('''Runtime vs Matrix Sizes by fixing number of threads
BLOCK SIZE - 16''')
plt.xlabel("Matrix Sizes by fixing number of threads as 8")
plt.ylabel("RunTime")
plt.show()

# %%
x = [512,1024,2048]
y = [0.381184,3.896084,34.163785]
plt.plot(x,y)
plt.title('''Runtime vs Matrix Sizes by fixing number of threads
BLOCK SIZE - 16''')
plt.xlabel("Matrix Sizes by fixing number of threads as 10")
plt.ylabel("RunTime")
plt.show()

# %%
x = [512,1024,2048]
y = [0.355813,3.57646,33.226466]
plt.plot(x,y)
plt.title('''Runtime vs Matrix Sizes by fixing number of threads
BLOCK SIZE - 16''')
plt.xlabel("Matrix Sizes by fixing number of threads as 12")
plt.ylabel("RunTime")
plt.show()

# %%
x = [512,1024,2048]
y = [0.522785,3.970834,32.52221]
plt.plot(x,y)
plt.title('''Runtime vs Matrix Sizes by fixing number of threads
BLOCK SIZE - 16''')
plt.xlabel("Matrix Sizes by fixing number of threads as 14")
plt.ylabel("RunTime")
plt.show()

# %%
x = [512,1024,2048]
y = [0.370319,4.134643,33.66774]
plt.plot(x,y)
plt.title('''Runtime vs Matrix Sizes by fixing number of threads
BLOCK SIZE - 16''')
plt.xlabel("Matrix Sizes by fixing number of threads as 16")
plt.ylabel("RunTime")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = [512,1024,2048]
y = [1.227233 ,	8.877270 ,	72.353977 ]
plt.plot(x,y)
plt.title('''Runtime vs Matrix Sizes by fixing number of threads
BLOCK SIZE - 64''')
plt.xlabel("Matrix Sizes by fixing number of threads as 2")
plt.ylabel("RunTime")
plt.show()

# %%
x = [512,1024,2048]
y = [0.674102 ,	5.350772  ,	41.776018  ]
plt.plot(x,y)
plt.title('''Runtime vs Matrix Sizes by fixing number of threads
BLOCK SIZE - 64''')
plt.xlabel("Matrix Sizes by fixing number of threads as 4")
plt.ylabel("RunTime")
plt.show()

# %%
x = [512,1024,2048]
y = [0.570532 ,3.876525 ,30.783862 ]
plt.plot(x,y)
plt.title('''Runtime vs Matrix Sizes by fixing number of threads
BLOCK SIZE - 64''')
plt.xlabel("Matrix Sizes by fixing number of threads as 6")
plt.ylabel("RunTime")
plt.show()

# %%
x = [512,1024,2048]
y = [0.482821 ,	3.670245 ,	29.409286 ]
plt.plot(x,y)
plt.title('''Runtime vs Matrix Sizes by fixing number of threads
BLOCK SIZE - 64''')
plt.xlabel("Matrix Sizes by fixing number of threads as 8")
plt.ylabel("RunTime")
plt.show()

# %%
x = [512,1024,2048]
y = [0.532898 ,	3.740830 , 31.044116]
plt.plot(x,y)
plt.title('''Runtime vs Matrix Sizes by fixing number of threads
BLOCK SIZE - 64''')
plt.xlabel("Matrix Sizes by fixing number of threads as 10")
plt.ylabel("RunTime")
plt.show()

# %%
x = [512,1024,2048]
y = [0.515309 ,	3.726247 , 29.717245]
plt.plot(x,y)
plt.title('''Runtime vs Matrix Sizes by fixing number of threads
BLOCK SIZE - 64''')
plt.xlabel("Matrix Sizes by fixing number of threads as 12")
plt.ylabel("RunTime")
plt.show()

# %%
x = [512,1024,2048]
y = [0.487377 ,	3.794126 ,	29.465323]
plt.plot(x,y)
plt.title('''Runtime vs Matrix Sizes by fixing number of threads
BLOCK SIZE - 64''')
plt.xlabel("Matrix Sizes by fixing number of threads as 14")
plt.ylabel("RunTime")
plt.show()

# %%
x = [512,1024,2048]
y = [0.469045 ,	3.679119 ,	30.164000]
plt.plot(x,y)
plt.title('''Runtime vs Matrix Sizes by fixing number of threads
BLOCK SIZE - 64''')
plt.xlabel("Matrix Sizes by fixing number of threads as 16")
plt.ylabel("RunTime")
plt.show()

# %% [markdown]
# T-OMM THREADS VS RUNTIME & MATRIX SIZE CONSTANT

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = [1,2,4,6,8,10,12,14,16]
y = [2.016789 ,1.115039 ,0.644415 ,0.460343 ,0.344344 ,0.373229 ,0.353232 ,0.368044 ,0.366113]

plt.bar(x,y)
plt.title('''Matrix size 512 by Using T-OMM, Exponent 2 ''')
plt.xlabel("Threads by fixing the Matrix Size")
plt.ylabel("RunTime")
plt.show()

# %%
x = [1,2,4,6,8,10,12,14,16]
y = [3.649521 , 1.756212 , 1.010216 , 0.690841 , 0.541018 , 0.56993 , 0.555021 ,0.567733 , 0.501803]

plt.bar(x,y)
plt.title('''Matrix size 512 by Using T-OMM, Exponent 3 ''')
plt.xlabel("Threads by fixing the Matrix Size")
plt.ylabel("RunTime")
plt.show()

# %%
x = [1,2,4,6,8,10,12,14,16]
y = [3.003438 ,
     1.671335,
0.968121,
0.686942,
0.5566,
0.604333,
0.535735,
0.562187,
0.580863]

plt.bar(x,y)
plt.title('''Matrix size 512 by Using T-OMM, Exponent 4 ''')
plt.xlabel("Threads by fixing the Matrix Size")
plt.ylabel("RunTime")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = [1,2,4,6,8,10,12,14,16]
y = [4.020446,
2.220534,
1.439133,
1.117215,
0.714772,
0.794474,
0.723887,
0.706113,
0.762332]

plt.bar(x,y)
plt.title('''Matrix size 512 by Using T-OMM, Exponent 5 ''')
plt.xlabel("Threads by fixing the Matrix Size")
plt.ylabel("RunTime")
plt.show()

# %%
x = [1,2,4,6,8,10,12,14,16]
y = [4.012416,
2.259153,
1.299459,
0.943068,
0.691837,
0.768016,
0.723295,
0.701835,
0.696435]

plt.bar(x,y)
plt.title('''Matrix size 512 by Using T-OMM, Exponent 6 ''')
plt.xlabel("Threads by fixing the Matrix Size")
plt.ylabel("RunTime")
plt.show()

# %%
x = [1,2,4,6,8,10,12,14,16]
y = [5.12186,
2.636587,
1.653341,
1.114651,
0.871214,
0.97393,
0.89033,
0.909378,
0.875745]

plt.bar(x,y)
plt.title('''Matrix size 512 by Using T-OMM, Exponent 7 ''')
plt.xlabel("Threads by fixing the Matrix Size")
plt.ylabel("RunTime")
plt.show()

# %%
x = [1,2,4,6,8,10,12,14,16]
y = [4.062322,
2.060782,
1.283671,
0.882426,
0.65315,
0.784818,
0.717748,
0.713112,
0.719099]

plt.bar(x,y)
plt.title('''Matrix size 512 by Using T-OMM, Exponent 8 ''')
plt.xlabel("Threads by fixing the Matrix Size")
plt.ylabel("RunTime")
plt.show()

# %%
x = [1,2,4,6,8,10,12,14,16]
y = [5.043399,
2.774087,
1.51669,
1.139194,
0.893935,
0.98615,
0.969627,
0.87724,
0.883453]

plt.bar(x,y)
plt.title('''Matrix size 512 by Using T-OMM, Exponent 9 ''')
plt.xlabel("Threads by fixing the Matrix Size")
plt.ylabel("RunTime")
plt.show()

# %%
x = [1,2,4,6,8,10,12,14,16]
y = [5.388134,2.701756,1.584082,1.174347,0.867923,1.000166,0.89069,0.865088,0.859449]

plt.bar(x,y)
plt.title('''Matrix size 512 by Using T-OMM, Exponent 10 ''')
plt.xlabel("Threads by fixing the Matrix Size")
plt.ylabel("RunTime")
plt.show()

# %% [markdown]
# T-BMM THREADS VS RUNTIME & MATRIX SIZE CONSTANT

# %%
x = [2,4,6,8,10,12,14,16]
y = [26.472498,
13.39573,
14.396526,
10.940922,
10.842222,
10.392238,
10.233278,
9.999048]
plt.bar(x,y)
plt.title('''Matrix size 2048 by Using T-BMM,
block size 4 , Exponent 2''')
plt.xlabel("Threads by fixing the Matrix Size")
plt.ylabel("RunTime")
plt.show()

# %%
x = [2,4,6,8,10,12,14,16]
y = [26.47	,
13.4,
14.4,
10.94,
10.84,
10.39	,
10.23	,
9.99	]
plt.bar(x,y)
plt.title('''Matrix size 2048 by Using T-BMM,
block size 8 , Exponent 2''')
plt.xlabel("Threads by fixing the Matrix Size")
plt.ylabel("RunTime")
plt.show()

# %%
x = [2,4,6,8,10,12,14,16]
y = [22.31,
11.58,
12.24,
9.5,
9.15,
8.79,
8.67,
8.52	]
plt.bar(x,y)
plt.title('''Matrix size 2048 by Using T-BMM,
block size 16 , Exponent 2''')
plt.xlabel("Threads by fixing the Matrix Size")
plt.ylabel("RunTime")
plt.show()

# %%
x = [2,4,6,8,10,12,14,16]
y = [
21.77,
11.31,
12.07,
9.55,
9.04,
8.65,
8.49,
8.3	]
plt.bar(x,y)
plt.title('''Matrix size 2048 by Using T-BMM,
block size 32 , Exponent 2''')
plt.xlabel("Threads by fixing the Matrix Size")
plt.ylabel("RunTime")
plt.show()

# %%
x = [2,4,6,8,10,12,14,16]
y = [
21.98,
11.35,
12.71,
9.55,
9.28,
9.01,
8.86,
8.32		]
plt.bar(x,y)
plt.title('''Matrix size 2048 by Using T-BMM,
block size 64 , Exponent 2''')
plt.xlabel("Threads by fixing the Matrix Size")
plt.ylabel("RunTime")
plt.show()

# %%
x = [2,4,6,8,10,12,14,16]
y = [
3.17,
1.65,
1.75,
1.34,
1.35,
1.43,
1.37,
1.33		]
plt.bar(x,y)
plt.title('''Matrix size 1024 by Using T-BMM,
 block size 4, Exponent 2 ''')
plt.xlabel("Threads by fixing the Matrix Size")
plt.ylabel("RunTime")
plt.show()

# %%
x = [2,4,6,8,10,12,14,16]
y = [2.89,
1.51,
1.59,
1.21,
1.25,
1.25,
1.24,
1.22
	]
plt.bar(x,y)
plt.title('''Matrix size 1024 by Using T-BMM,
 block size 8, Exponent 2 ''')
plt.xlabel("Threads by fixing the Matrix Size")
plt.ylabel("RunTime")
plt.show()

# %%
x = [2,4,6,8,10,12,14,16]
y = [2.79,
1.47,
1.55,
1.17,
1.22,
1.26,
1.17,
1.13
	]
plt.bar(x,y)
plt.title('''Matrix size 1024 by Using T-BMM,
 block size 16, Exponent 2 ''')
plt.xlabel("Threads by fixing the Matrix Size")
plt.ylabel("RunTime")
plt.show()

# %%
x = [2,4,6,8,10,12,14,16]
y = [2.72,
1.43,
1.49,
1.22,
1.17,
1.24,
1.13,
1.15
	]
plt.bar(x,y)
plt.title('''Matrix size 1024 by Using T-BMM,
 block size 32, Exponent 2 ''')
plt.xlabel("Threads by fixing the Matrix Size")
plt.ylabel("RunTime")
plt.show()

# %%
x = [2,4,6,8,10,12,14,16]
y = [2.71,
1.44,
1.57,
1.24,
1.21,
1.27,
1.25,
1.14]

plt.bar(x,y)
plt.title('''Matrix size 1024 by Using T-BMM,
 block size 64, Exponent 2 ''')
plt.xlabel("Threads by fixing the Matrix Size")
plt.ylabel("RunTime")
plt.show()

# %%
x = [2,4,6,8,10,12,14,16]
y = [0.418395,
0.234714,
0.22646,
0.188121,
0.200982,
0.208821,
0.207173,
0.203685]

plt.bar(x,y)
plt.title('''Matrix size 512 by Using T-BMM,
 block size 4, Exponent 2 ''')
plt.xlabel("Threads by fixing the Matrix Size")
plt.ylabel("RunTime")
plt.show()

# %%
x = [2,4,6,8,10,12,14,16]
y = [0.363299,
0.216517,
0.216267,
0.178971,
0.188706,
0.174403,
0.193975,
0.18335]

plt.bar(x,y)
plt.title('''Matrix size 512 by Using T-BMM,
 block size 8, Exponent 2 ''')
plt.xlabel("Threads by fixing the Matrix Size")
plt.ylabel("RunTime")
plt.show()

# %%
x = [2,4,6,8,10,12,14,16]
y = [0.35761,
0.212266,
0.200601,
0.170561,
0.170115,
0.175084,
0.179456,
0.17134]

plt.bar(x,y)
plt.title('''Matrix size 512 by Using T-BMM,
 block size 16, Exponent 2 ''')
plt.xlabel("Threads by fixing the Matrix Size")
plt.ylabel("RunTime")
plt.show()

# %%
x = [2,4,6,8,10,12,14,16]
y = [0.345696,
0.207922,
0.212966,
0.174651,
0.17502,
0.17638,
0.170957,
0.182593]

plt.bar(x,y)
plt.title('''Matrix size 512 by Using T-BMM,
 block size 32, Exponent 2 ''')
plt.xlabel("Threads by fixing the Matrix Size")
plt.ylabel("RunTime")
plt.show()

# %%
x = [2,4,6,8,10,12,14,16]
y = [0.345595,
0.202754,
0.175689,
0.176965,
0.163984,
0.170611,
0.17996,
0.172127]

plt.bar(x,y)
plt.title('''Matrix size 512 by Using T-BMM,
 block size 64, Exponent 2 ''')
plt.xlabel("Threads by fixing the Matrix Size")
plt.ylabel("RunTime")
plt.show()

# %%
x = [2,4,6,8,10,12,14,16]
y = [1.587216,
0.845864,
0.877298,
0.723363,
0.731022,
0.746594,
0.768257,
0.735372]

plt.bar(x,y)
plt.title('''Matrix size 512 by Using T-BMM,
 block size 4, Exponent 8 ''')
plt.xlabel("Threads by fixing the Matrix Size")
plt.ylabel("RunTime")
plt.show()

# %%
x = [2,4,6,8,10,12,14,16]
y = [1.453969,
0.762955,
0.831289,
0.672483,
0.653012,
0.642761,
0.661433,
0.674807]

plt.bar(x,y)
plt.title('''Matrix size 512 by Using T-BMM,
 block size 8, Exponent 8 ''')
plt.xlabel("Threads by fixing the Matrix Size")
plt.ylabel("RunTime")
plt.show()

# %%
x = [2,4,6,8,10,12,14,16]
y = [1.407378,
0.740043,
0.793288,
0.705083,
0.651132,
0.676453,
0.704636,
0.631251,]

plt.bar(x,y)
plt.title('''Matrix size 512 by Using T-BMM,
 block size 16, Exponent 8 ''')
plt.xlabel("Threads by fixing the Matrix Size")
plt.ylabel("RunTime")
plt.show()

# %%
x = [2,4,6,8,10,12,14,16]
y = [1.386121,
0.733144,
0.80465,
0.759093,
0.7699,
0.78026,
0.803967,
0.775406]

plt.bar(x,y)
plt.title('''Matrix size 512 by Using T-BMM,
 block size 32, Exponent 8 ''')
plt.xlabel("Threads by fixing the Matrix Size")
plt.ylabel("RunTime")
plt.show()

# %%
x = [2,4,6,8,10,12,14,16]
y = [1.410397,
0.720504,
0.852369,
0.707389,
0.717801,
0.679345,
0.702548,
0.692749]

plt.bar(x,y)
plt.title('''Matrix size 512 by Using T-BMM,
 block size 64, Exponent 8 ''')
plt.xlabel("Threads by fixing the Matrix Size")
plt.ylabel("RunTime")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = [2,4,6,8,10,12,14,16]
y = [12.589027,
6.540148,
6.999416,
5.341029,
5.601003,
5.34618,
5.405156,
5.305399]

plt.bar(x,y)
plt.title('''Matrix size 1024 by Using T-BMM,
 block size 4, Exponent 8 ''')
plt.xlabel("Threads by fixing the Matrix Size")
plt.ylabel("RunTime")
plt.show()

# %%
x = [2,4,6,8,10,12,14,16]
y = [11.56242,
5.965736,
6.381747,
4.822665,
5.098495,
5.343111,
5.384569,
5.174278,]

plt.bar(x,y)
plt.title('''Matrix size 1024 by Using T-BMM,
 block size 8, Exponent 8 ''')
plt.xlabel("Threads by fixing the Matrix Size")
plt.ylabel("RunTime")
plt.show()

# %%
x = [2,4,6,8,10,12,14,16]
y = [11.224708,
5.808347,
6.204039,
4.951015,
5.20143,
5.485888,
5.37571,
5.285314,]

plt.bar(x,y)
plt.title('''Matrix size 1024 by Using T-BMM,
 block size 16, Exponent 8 ''')
plt.xlabel("Threads by fixing the Matrix Size")
plt.ylabel("RunTime")
plt.show()

# %%
x = [2,4,6,8,10,12,14,16]
y = [11.241335,
5.660291,
6.100069,
4.593742,
4.91409,
4.732003,
4.853582,
4.474018,]

plt.bar(x,y)
plt.title('''Matrix size 1024 by Using T-BMM,
 block size 32, Exponent 8 ''')
plt.xlabel("Threads by fixing the Matrix Size")
plt.ylabel("RunTime")
plt.show()

# %%
x = [2,4,6,8,10,12,14,16]
y = [10.900572,
5.635241,
6.152187,
4.726818,
5.13337,
5.229324,
5.052691,
4.806616,]

plt.bar(x,y)
plt.title('''Matrix size 1024 by Using T-BMM,
 block size 64, Exponent 8 ''')
plt.xlabel("Threads by fixing the Matrix Size")
plt.ylabel("RunTime")
plt.show()

# %%
x = [2,4,6,8,10,12,14,16]
y = [103.505728,
53.516643,
57.505745,
44.125783,
44.432867,
41.726458,
40.886564,
40.290719,]

plt.bar(x,y)
plt.title('''Matrix size 2048 by Using T-BMM,
 block size 4, Exponent 8 ''')
plt.xlabel("Threads by fixing the Matrix Size")
plt.ylabel("RunTime")
plt.show()

# %%
x = [2,4,6,8,10,12,14,16]
y = [92.181353,
47.970803,
51.452725,
41.393505,
39.318914,
38.580196,
37.41253,
37.816008,]

plt.bar(x,y)
plt.title('''Matrix size 2048 by Using T-BMM,
 block size 8, Exponent 8 ''')
plt.xlabel("Threads by fixing the Matrix Size")
plt.ylabel("RunTime")
plt.show()

# %%
x = [2,4,6,8,10,12,14,16]
y = [90.687516,
46.528905,
49.617836,
37.428198,
37.98968,
35.403412,
34.79695,
34.444137,]

plt.bar(x,y)
plt.title('''Matrix size 2048 by Using T-BMM,
 block size 16, Exponent 8 ''')
plt.xlabel("Threads by fixing the Matrix Size")
plt.ylabel("RunTime")
plt.show()

# %%
x = [2,4,6,8,10,12,14,16]
y = [87.788791,
45.219031,
47.945595,
36.34984,
36.657992,
35.306719,
34.183578,
33.201294,]

plt.bar(x,y)
plt.title('''Matrix size 2048 by Using T-BMM,
 block size 32, Exponent 8 ''')
plt.xlabel("Threads by fixing the Matrix Size")
plt.ylabel("RunTime")
plt.show()

# %%
x = [2,4,6,8,10,12,14,16]
y = [88.31776,
45.450142,
50.606816,
37.013002,
37.25862,
35.848829,
35.671826,
33.539505,]

plt.bar(x,y)
plt.title('''Matrix size 2048 by Using T-BMM,
 block size 64, Exponent 8 ''')
plt.xlabel("Threads by fixing the Matrix Size")
plt.ylabel("RunTime")
plt.show()

# %% [markdown]
# T-OMM Threads Constant, time vs matrix size and exponent

# %% [markdown]
# Omm exponent 4

# %%
x = [512,1024,2048]
y = [0.934472,
     9.49674,
     83.558339,]
plt.plot(x,y)
plt.title('''Runtime vs Matrix Sizes by fixing number of threads
exponent 4
''')
plt.xlabel("Matrix Sizes by fixing number of threads as 4")
plt.ylabel("RunTime")
plt.show()

# %%
x = [512,1024,2048]
y = [0.926519	,
     9.613349	,
     83.600345,	]
plt.plot(x,y)
plt.title('''Runtime vs Matrix Sizes by fixing number of threads
exponent 4
''')
plt.xlabel("Matrix Sizes by fixing number of threads as 10")
plt.ylabel("RunTime")
plt.show()

# %%
x = [512,1024,2048]
y = [0.925442	,
     9.629515	,
     85.057505,	]
plt.plot(x,y)
plt.title('''Runtime vs Matrix Sizes by fixing number of threads,
exponent 4
''')
plt.xlabel("Matrix Sizes by fixing number of threads as 16")
plt.ylabel("RunTime")
plt.show()

# %%
Exponent 10

# %%
x = [512,1024,2048]
y = [1.607493,
16.084562,
141.389744,]
plt.plot(x,y)
plt.title('''Runtime vs Matrix Sizes by fixing number of threads
exponent 10

''')
plt.xlabel("Matrix Sizes by fixing number of threads as 4")
plt.ylabel("RunTime")
plt.show()

# %%
x = [512,1024,2048]
y = [1.584427,
16.001004,
140.036846,]
plt.plot(x,y)
plt.title('''Runtime vs Matrix Sizes by fixing number of threads , exponent 10

''')
plt.xlabel("Matrix Sizes by fixing number of threads as 10")
plt.ylabel("RunTime")
plt.show()

# %%
x = [512,1024,2048]
y = [1.606809,
16.034053,
142.996357,]
plt.plot(x,y)
plt.title('''Runtime vs Matrix Sizes by fixing number of threads
exponent 10
''')
plt.xlabel("Matrix Sizes by fixing number of threads as 16")
plt.ylabel("RunTime")
plt.show()

# %% [markdown]
# Exponent 16

# %%
x = [512,1024,2048]
y = [1.619638,
16.190143,
145.049501,]
plt.plot(x,y)
plt.title('''Runtime vs Matrix Sizes by fixing number of threads
exponent 16
''')
plt.xlabel("Matrix Sizes by fixing number of threads as 4, ")
plt.ylabel("RunTime")
plt.show()

# %%
x = [512,1024,2048]
y = [1.590882,
16.09468,
143.49295,]
plt.plot(x,y)
plt.title('''Runtime vs Matrix Sizes by fixing number of threads
exponent 4
''')
plt.xlabel("Matrix Sizes by fixing number of threads as 10")
plt.ylabel("RunTime")
plt.show()

# %%
x = [512,1024,2048]
y = [1.602858,
16.102856,
142.565639,]
plt.plot(x,y)
plt.title('''Runtime vs Matrix Sizes by fixing number of threads
exponent 16
''')
plt.xlabel("Matrix Sizes by fixing number of threads as 16")
plt.ylabel("RunTime")
plt.show()

# %% [markdown]
# Tbmm , threads constant

# %%
x = [512,1024,2048]
y = [0.203735,
1.369195,
10.939835,]
plt.plot(x,y)
plt.title('''Runtime vs Matrix Sizes by fixing number of threads
BLOCK SIZE - 4, Exponent - 2''')
plt.xlabel("Matrix Sizes by fixing number of threads as 8")
plt.ylabel("RunTime")
plt.show()

# %%
x = [512,1024,2048]
y = [0.168332,
1.23798,
9.334919,]
plt.plot(x,y)
plt.title('''Runtime vs Matrix Sizes by fixing number of threads
BLOCK SIZE - 16 , Exponent - 2''')
plt.xlabel("Matrix Sizes by fixing number of threads as 8")
plt.ylabel("RunTime")
plt.show()

# %%
x = [512,1024,2048]
y = [0.162323,
1.218452,
9.178343,]
plt.plot(x,y)
plt.title('''Runtime vs Matrix Sizes by fixing number of threads
BLOCK SIZE - 64, Exponent - 2''')
plt.xlabel("Matrix Sizes by fixing number of threads as 8")
plt.ylabel("RunTime")
plt.show()

# %%
x = [512,1024,2048]
y = [0.708532,
5.513588,
45.727285,]
plt.plot(x,y)
plt.title('''Runtime vs Matrix Sizes by fixing number of threads
BLOCK SIZE - 4, exponent: 8''')
plt.xlabel("Matrix Sizes by fixing number of threads as 8")
plt.ylabel("RunTime")
plt.show()

# %%
x = [512,1024,2048]
y = [0.610096,
4.748413,
38.992599,]
plt.plot(x,y)
plt.title('''Runtime vs Matrix Sizes by fixing number of threads
BLOCK SIZE - 16, exponent: 8''')
plt.xlabel("Matrix Sizes by fixing number of threads as 8")
plt.ylabel("RunTime")
plt.show()

# %%
x = [512,1024,2048]
y = [0.58938,
4.634459,
39.269111,]
plt.plot(x,y)
plt.title('''Runtime vs Matrix Sizes by fixing number of threads
BLOCK SIZE - 64, exponent: 8''')
plt.xlabel("Matrix Sizes by fixing number of threads as 8")
plt.ylabel("RunTime")
plt.show()

# %%
x = [512,1024,2048]
y = [1.432047,
10.787191,
88.594809,]
plt.plot(x,y)
plt.title('''Runtime vs Matrix Sizes by fixing number of threads
BLOCK SIZE - 4, exponent: 16''')
plt.xlabel("Matrix Sizes by fixing number of threads as 8")
plt.ylabel("RunTime")
plt.show()

# %%
x = [512,1024,2048]
y = [1.286139,
9.635162,
74.917294,]
plt.plot(x,y)
plt.title('''Runtime vs Matrix Sizes by fixing number of threads
BLOCK SIZE - 16, exponent: 16''')
plt.xlabel("Matrix Sizes by fixing number of threads as 8")
plt.ylabel("RunTime")
plt.show()

# %%
x = [512,1024,2048]
y = [1.175176,
10.622436,
73.682946,]
plt.plot(x,y)
plt.title('''Runtime vs Matrix Sizes by fixing number of threads
BLOCK SIZE - 64, exponent: 16''')
plt.xlabel("Matrix Sizes by fixing number of threads as 8")
plt.ylabel("RunTime")
plt.show()

# %% [markdown]
# Tbmm, threads = 16

# %%
x = [512,1024,2048]
y = [1.432047,
10.787191,
88.594809,]
plt.plot(x,y)
plt.title('''Runtime vs Matrix Sizes by fixing number of threads
BLOCK SIZE - 4 exponent: 2''')
plt.xlabel("Matrix Sizes by fixing number of threads as 16")
plt.ylabel("RunTime")
plt.show()

# %%
x = [512,1024,2048]
y = [1.286139,
9.635162,
74.917294,]
plt.plot(x,y)
plt.title('''Runtime vs Matrix Sizes by fixing number of threads
BLOCK SIZE - 16, exponent: 2''')
plt.xlabel("Matrix Sizes by fixing number of threads as 16")
plt.ylabel("RunTime")
plt.show()

# %%
x = [512,1024,2048]
y = [1.175176,
10.622436,
73.682946,]
plt.plot(x,y)
plt.title('''Runtime vs Matrix Sizes by fixing number of threads
BLOCK SIZE - 64, exponent: 2''')
plt.xlabel("Matrix Sizes by fixing number of threads as 16")
plt.ylabel("RunTime")
plt.show()

# %%
x = [512,1024,2048]
y = [0.796101,
5.203494,
40.158863,]
plt.plot(x,y)
plt.title('''Runtime vs Matrix Sizes by fixing number of threads
BLOCK SIZE - 4, exponent: 8''')
plt.xlabel("Matrix Sizes by fixing number of threads as 16")
plt.ylabel("RunTime")
plt.show()

# %%
x = [512,1024,2048]
y = [0.657555,
4.617621,
34.246556,]
plt.plot(x,y)
plt.title('''Runtime vs Matrix Sizes by fixing number of threads
BLOCK SIZE - 16, exponent: 8''')
plt.xlabel("Matrix Sizes by fixing number of threads as 16")
plt.ylabel("RunTime")
plt.show()

# %%
x = [512,1024,2048]
y = [0.653013,
4.593701,
33.483999,]
plt.plot(x,y)
plt.title('''Runtime vs Matrix Sizes by fixing number of threads
BLOCK SIZE - 64, exponent: 8''')
plt.xlabel("Matrix Sizes by fixing number of threads as 16")
plt.ylabel("RunTime")
plt.show()

# %%
x = [512,1024,2048]
y = [1.502629,
10.688437,
85.08919,]
plt.plot(x,y)
plt.title('''Runtime vs Matrix Sizes by fixing number of threads
BLOCK SIZE - 4 , exponent: 16''')
plt.xlabel("Matrix Sizes by fixing number of threads as 16")
plt.ylabel("RunTime")
plt.show()

# %%
x = [512,1024,2048]
y = [1.308875,
9.236936,
68.603911,]
plt.plot(x,y)
plt.title('''Runtime vs Matrix Sizes by fixing number of threads
BLOCK SIZE - 16, exponent: 16''')
plt.xlabel("Matrix Sizes by fixing number of threads as 16")
plt.ylabel("RunTime")
plt.show()

# %%
x = [512,1024,2048]
y = [1.244589,
9.015008,
67.086486,]
plt.plot(x,y)
plt.title('''Runtime vs Matrix Sizes by fixing number of threads
BLOCK SIZE - 64, exponent: 16''')
plt.xlabel("Matrix Sizes by fixing number of threads as 16")
plt.ylabel("RunTime")
plt.show()
